# %% [markdown]
# <a href="https://colab.research.google.com/github/Amir-Ali-Peymani/ML-practice/blob/main/02_pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Import pandas

# %%
import pandas as pd
import numpy as np
# pandas is more about data
# numpy is more dealing with numbers

# %% [markdown]
# WRITING PRACTICE

# %%
pd.Series([1,2,3,"amir ali",0, np.nan, -2])
# Out:
# 0           1
# 1           2
# 2           3
# 3    amir ali
# 4           0
# 5         NaN
# 6          -2
# dtype: object

# %%
dates = pd.date_range("20211202", periods=6)
dates
# Out:
# DatetimeIndex(['2021-12-02', '2021-12-03', '2021-12-04', '2021-12-05',
#                '2021-12-06', '2021-12-07'],
#               dtype='datetime64[ns]', freq='D')

# %%
np.random.randn(6,4)
# Out:
# array([[-0.61220855, -0.68247984, -0.40957842,  1.07331013],
#        [ 0.35530478, -0.03025564, -2.17542521,  1.28594103],
#        [ 1.07814733, -0.81858731, -2.02312752, -0.90453585],
#        [-0.30260355, -1.69525608,  1.01141852, -1.51726647],
#        [-0.68134785,  0.0247302 , -0.35533648, -0.54741108],
#        [-1.42884961, -0.06296492, -1.21346129,  1.35475983]])

# %%
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=["A","B","C","D"])
df
# Out:
#                    A         B         C         D
# 2021-12-02 -1.390705  0.124194  1.628105  1.487216
# 2021-12-03 -0.793566  0.447581  0.026945  0.299210
# 2021-12-04  0.682297 -0.952413  0.346602  1.150467
# 2021-12-05  1.269975  0.399685  0.495049  1.198686
# 2021-12-06  0.423800 -0.232360  0.606739 -0.090264
# 2021-12-07 -0.397768 -0.039414 -0.628582  0.000575

# %%
df["A"]
# Out:
# 2021-12-02   -1.390705
# 2021-12-03   -0.793566
# 2021-12-04    0.682297
# 2021-12-05    1.269975
# 2021-12-06    0.423800
# 2021-12-07   -0.397768
# Freq: D, Name: A, dtype: float64

# %%
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean  -0.034328 -0.042121  0.412476  0.674315
# std    0.997289  0.515265  0.742844  0.684354
# min   -1.390705 -0.952413 -0.628582 -0.090264
# 25%   -0.694616 -0.184124  0.106859  0.075233
# 50%    0.013016  0.042390  0.420826  0.724839
# 75%    0.617673  0.330812  0.578816  1.186631
# max    1.269975  0.447581  1.628105  1.487216

# %%
df.mean()
# Out:
# A   -0.034328
# B   -0.042121
# C    0.412476
# D    0.674315
# dtype: float64

# %%
df.T
# Out:
#    2021-12-02  2021-12-03  2021-12-04  2021-12-05  2021-12-06  2021-12-07
# A   -1.390705   -0.793566    0.682297    1.269975    0.423800   -0.397768
# B    0.124194    0.447581   -0.952413    0.399685   -0.232360   -0.039414
# C    1.628105    0.026945    0.346602    0.495049    0.606739   -0.628582
# D    1.487216    0.299210    1.150467    1.198686   -0.090264    0.000575
